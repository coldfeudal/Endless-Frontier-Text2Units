# %%
keys = [
	"EA",
	"INF",
	"OF",
	"SU",
	"EW",
	"Frost",
	"HI",
	"OH",
	"PA",
	"Lock",
	"Ghost",
	"FB",
	"HK",
	"HEA",
	"GE",
	"GHU",
	"Musk",
	"OHU",
	"OW",
	"SW",
	"BMW",
	"CK",
	"OAU",
	"WM",
	"AL",
	"Alch",
	"AM",
	"BD, Drummer",
	"BF",
	"BM",
	"BU",
	"Cleric",
	"Crow",
	"DA",
	"DaD",
	"DE",
	"DK",
	"Druid",
	"DS",
	"Elem",
	"Ent",
	"Fairy",
	"FD",
	"FG",
	"FM",
	"FS",
	"Goku",
	"Golem",
	"GR",
	"Gunner",
	"HB",
	"HG, Hippo",
	"HoD",
	"INC",
	"IS",
	"IW",
	"Lich",
	"Med, Dusa, MoM",
	"Naga",
	"NoD",
	"Pilot",
	"Priest",
	"Rangda",
	"Raptor, RR",
	"Sage",
	"SD",
	"Siren",
	"Sorc",
	"SP",
	"Succ",
	"Sylph",
	"Tress",
	"UK",
	"Valk",
	"Wiwa",
	"WK",
	"WR",
	"WW",
	"Wyvern"
]

vals = [
    "Elf Archer",
    "Infantry",
    "Orc Fighter",
    "Skeleton Unit",
    "Elf Warrior",
    "Frost Mage",
    "Heavy Infantry",
    "Orc Hunter",
    "Poison Archer",
    "Warlock",
    "Ghost",
    "Fire Bird",
    "Hammer Knight",
    "High Elf Archer",
    "Green Eagle",
    "Great Hammer Unit",
    "Musketeer",
    "Orc Hammer Unit",
    "Orc Wing",
    "Skeleton Warrior",
    "Black Magic Wizard",
    "Cavalry Knight",
    "Orc Ax Unit",
    "Wind Mage",
    "Aladdin",
    "Alchemist",
    "Abyss Mage",
    "Battle Drummer",
    "Big Foot",
    "Blade Master",
    "Bomb Unit",
    "Cleric",
    "Crow Knight",
    "Dark Archer",
    "Dark Admiral",
    "Dark Elf",
    "Death Knight",
    "Druid",
    "Dark Spirit",
    "Elementalist",
    "Ent",
    "Fairy",
    "Frost Demon",
    "Forest Guardian",
    "Fire Mage",
    "Fire Spirit",
    "Hoyden Goku",
    "Golem",
    "Griffin Rider",
    "Gunner",
    "Hot-Blooded Xuanzang",
    "Hippogriff",
    "Hands of Death",
    "Incubus",
    "Ice Spirit",
    "Ice Wizard",
    "Lich",
    "Medusa",
    "Naga",
    "Dark Ninja",
    "Pilot",
    "Priest",
    "Rangda",
    "Raptor Rider",
    "Elf Sage",
    "Sword Dancer",
    "Siren",
    "Sorcerer",
    "Steam Punk",
    "Succubus",
    "Sylphid",
    "Musketress",
    "Unicorn Knight",
    "Valkyrie",
    "Windwalker",
    "Winged Knight",
    "Wolf Rider",
    "Wolf Warrior",
    "Wyvern Rider"
]
stars = ["1"]*5 + ["2"]*8 + ["3"]*8 + ["4"]*4 + ["5"]*55

# %%
for key, val, star in zip(keys, vals, stars):
	print(f"INSERT INTO units (`name`, `short`, `star`) VALUES ('{val}', '{key.replace(', ', ' ')}', {star});")
# Out:
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Elf Archer', 'EA', 1);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Infantry', 'INF', 1);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Orc Fighter', 'OF', 1);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Skeleton Unit', 'SU', 1);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Elf Warrior', 'EW', 1);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Frost Mage', 'Frost', 2);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Heavy Infantry', 'HI', 2);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Orc Hunter', 'OH', 2);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Poison Archer', 'PA', 2);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Warlock', 'Lock', 2);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Ghost', 'Ghost', 2);
# INSERT INTO units (`name`, `short`, `star`) VALUES ('Fire Bird', 'FB', 2);
# ...

# %%
ru_keys = [
    "Elf Archer",
    "Infantry",
    "Orc Fighter",
    "Skeleton Unit",
    "Elf Warrior",
    "Frost Mage",
    "Heavy Infantry",
    "Orc Hunter",
    "Poison Archer",
    "Warlock",
    "Ghost",
    "Fire Bird",
    "Hammer Knight",
    "High Elf Archer",
    "Green Eagle",
    "Great Hammer Unit",
    "Musketeer",
    "Orc Hammer Unit",
    "Orc Wing",
    "Skeleton Warrior",
    "Black Magic Wizard",
    "Cavalry Knight",
    "Orc Ax Unit",
    "Wind Mage",
    "Aladdin",
    "Alchemist",
    "Abyss Mage",
    "Battle Drummer",
    "Big Foot",
    "Blade Master",
    "Bomb Unit",
    "Cleric",
    "Crow Knight",
    "Dark Archer",
    "Dark Admiral",
    "Dark Elf",
    "Death Knight",
    "Druid",
    "Dark Spirit",
    "Elementalist",
    "Ent",
    "Fairy",
    "Frost Demon",
    "Forest Guardian",
    "Fire Mage",
    "Fire Spirit",
    "Hoyden Goku",
    "Golem",
    "Griffin Rider",
    "Gunner",
    "Hot-Blooded Xuanzang",
    "Hippogriff",
    "Hands of Death",
    "Incubus",
    "Ice Spirit",
    "Ice Wizard",
    "Lich",
    "Medusa",
    "Naga",
    "Dark Ninja",
    "Pilot",
    "Priest",
    "Rangda",
    "Raptor Rider",
    "Elf Sage",
    "Sword Dancer",
    "Siren",
    "Sorcerer",
    "Steam Punk",
    "Succubus",
    "Sylphid",
    "Musketress",
    "Unicorn Knight",
    "Valkyrie",
    "Windwalker",
    "Winged Knight",
    "Wolf Rider",
    "Wolf Warrior",
    "Wyvern Rider"
]

ru_vals = [
    "Эльф-лучник",
    "Пехота",
    "Орк-боец",
    "Скелет",
    "Воин-эльф",
    "Ледяной маг",
    "Тяжёлая пехота",
    "Орк-охотник",
    "Лучник с ядом",
    "Колдун",
    "Призрак",
    "Огненная птица",
    "Рыцарь с молотом",
    "Высококлассный эльф-лучник",
    "Зелёный орел",
    "Воин с большим молотом",
    "Мушкетер",
    "Орк с молотом",
    "Крыло орка",
    "Воин-скелет",
    "Маг чёрной магии",
    "Рыцарь конницы",
    "Орк с топором",
    "Маг ветра",
    "Алладин",
    "Алхимик",
    "Адский маг",
    "Военный барабанщик ",
    "Снежный Человек",
    "Мастер клинка",
    "Бомбардировщик",
    "Клирик",
    "Рыцарь-ворон",
    "Тёмный лучник",
    "Тёмный адмирал",
    "Тёмный эльф",
    "Рыцарь смерти",
    "Друид",
    "Тёмный дух",
    "Элементалист",
    "Древень",
    "Фея",
    "Демон мороза",
    "Страж леса",
    "Огненный маг",
    "Огненный дух",
    "Сварливая многоножка",
    "Голем ",
    "Наездник на грифоне",
    "Артиллерист",
    "Горячий монах",
    "Гиппогриф",
    "Рука смерти",
    "Инкуб",
    "Ледяной дух",
    "Ледяной волшебник",
    "Лич",
    "Медуза",
    "Нага",
    "Ниндзя Тьмы",
    "Пилот",
    "Священник",
    "Рангда",
    "Наездник на рапторе",
    "Эльфийский мудрец",
    "Танцовщица с мечом",
    "Сирена",
    "Волшебник",
    "Стим-панк",
    "Суккуб",
    "Сильфид",
    "Мушкетерша",
    "Рыцарь на единороге",
    "Валькирия",
    "Шагающий по ветру",
    "Крылатый Рыцарь",
    "Наездник на волке",
    "Воин-волк",
    "Всадник на виверне"
]

# %%
for key, val in zip(ru_keys, ru_vals):
	print(f"UPDATE units SET `ru_name` = '{val}' WHERE `name` = '{key}';")
# Out:
# UPDATE units SET `ru_name` = 'Эльф-лучник' WHERE `name` = 'Elf Archer';
# UPDATE units SET `ru_name` = 'Пехота' WHERE `name` = 'Infantry';
# UPDATE units SET `ru_name` = 'Орк-боец' WHERE `name` = 'Orc Fighter';
# UPDATE units SET `ru_name` = 'Скелет' WHERE `name` = 'Skeleton Unit';
# UPDATE units SET `ru_name` = 'Воин-эльф' WHERE `name` = 'Elf Warrior';
# UPDATE units SET `ru_name` = 'Ледяной маг' WHERE `name` = 'Frost Mage';
# UPDATE units SET `ru_name` = 'Тяжёлая пехота' WHERE `name` = 'Heavy Infantry';
# UPDATE units SET `ru_name` = 'Орк-охотник' WHERE `name` = 'Orc Hunter';
# UPDATE units SET `ru_name` = 'Лучник с ядом' WHERE `name` = 'Poison Archer';
# UPDATE units SET `ru_name` = 'Колдун' WHERE `name` = 'Warlock';
# UPDATE units SET `ru_name` = 'Призрак' WHERE `name` = 'Ghost';
# UPDATE units SET `ru_name` = 'Огненная птица' WHERE `name` = 'Fire Bird';
# UPDATE units SET `ru_name` = 'Рыцарь с молотом' WHERE `name` = 'Hammer Knight';
# ...
